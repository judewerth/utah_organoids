# %% [markdown]
# # Pipeline Architecture Visualization for the DataJoint Workflow: Exploration of Schemas

# %% [markdown]
# This notebook explores the main schemas that compound the pipeline architecture for this project.

# %% [markdown]
# **_Note:_**
#
# - The examples in this notebook use a sample dataset. Replace these entries with your actual database entries to access and analyze your data.

# %% [markdown]
# ### **Key Steps**
#
# - **Setup**
#
# - **Schema Diagrams**

# %% [markdown]
# #### **Setup**

# %%
import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import datajoint as dj

# %%
from workflow.pipeline import lineage, culture, ephys, probe
# Out:
# [2024-07-17 16:07:48,546][INFO]: Connecting milagros@db.datajoint.com:3306
# [2024-07-17 16:07:50,189][INFO]: Connected milagros@db.datajoint.com:3306

# %% [markdown]
# #### **Schema Diagrams**

# %%
(dj.Diagram(lineage) + dj.Diagram(culture))

# %%
(dj.Diagram(probe) + dj.Diagram(ephys))
