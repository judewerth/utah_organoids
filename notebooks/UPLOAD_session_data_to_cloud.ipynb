# %% [markdown]
# # Uploading Ephys Data to the Cloud

# %% [markdown]
# ### **Overview**

# %% [markdown]
# This notebook provides a step-by-step guide to uploading electrophysiology (ephys) data to the cloud. Cloud storage ensures accessibility, scalability, and security for data processing and analysis.

# %% [markdown]
# **_Note:_**
#
# - This notebook uses example data—replace values with actual file paths.

# %% [markdown]
# ### **Key Steps**
#
# - **Setup**
#
# - **Step 1: Upload Data**

# %% [markdown]
# ### **Setup**

# %% [markdown]
# Begin by importing the necessary libraries for the data pipeline and key schemas.

# %%
## Ensure the correct working directory

import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import datajoint as dj

# %%
from workflow.utils.initiate_session import upload_session_data

# %% [markdown]
# #### **Step 1: Upload Data**

# %% [markdown]
# Before uploading, ensure your session data is correctly stored in the designated raw data directory.

# %% [markdown]
# #### Upload a Specific Session
#
# To upload a session, specify the relative folder name within the configured data directory.
#
# Example:
# If your raw data is stored in:
# `'/Users/milagros/Documents/data/organoids/inbox/test2'`
#
# And the root data directory is defined in:

# %%
dj.config["custom"]["raw_root_data_dir"]
# Out:
# '/Users/milagros/Documents/data/organoids/inbox'

# %% [markdown]
# Then initiate the upload as follows:

# %%
upload_session_data("test2")  # Update the name of the experiments folder

# %% [markdown]
# This will transfer the session data to the cloud storage.

# %% [markdown]
# ### **Verify Upload Completion**

# %% [markdown]
# After running the upload function, ensure the files are successfully transferred to the AWS S3 bucket or the designated cloud storage.
# - Check log messages for any errors.
# - Confirm the data exists by logging into [works.datajoint.com](works.datajoint.com)  and navigate to the `Files` tab.

# %% [markdown]
# ### **Next Steps**

# %% [markdown]
# Now that the data is uploaded, you can:
# - Create an ephys session using `CREATE_new_session.ipynb`.
