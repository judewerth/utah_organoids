# %%
import os 
if os.path.basename(os.getcwd()) == "notebooks": os.chdir("..")
import datajoint as dj
from workflow import protocol
# Out:
# [2022-10-04 15:36:59,714][INFO]: Connecting kabilar@rds.datajoint.io:3306
# [2022-10-04 15:37:00,245][INFO]: Connected kabilar@rds.datajoint.io:3306

# %%
dj.Diagram(protocol)
