# %%
import os 
if os.path.basename(os.getcwd()) == "notebooks": os.chdir("..")
import datajoint as dj
from workflow import differentiation, induction
# Out:
# [2022-11-29 14:44:10,445][INFO]: Connecting kabilar@rds.datajoint.io:3306
# [2022-11-29 14:44:10,794][INFO]: Connected kabilar@rds.datajoint.io:3306

# %%
dj.Diagram(differentiation) + dj.Diagram(induction)
