# %% [markdown]
# # Creating a New Clustering Parameter Set in the Utah Organoids Pipeline

# %% [markdown]
# ### **Overview**

# %% [markdown]
# This notebook guides users through the process of **defining and inserting a new clustering parameter set** for spike sorting within the Utah Organoids pipeline.
#
# A parameter set (`paramset_idx`) stores the settings used for **SpikeInterface sorting algorithms** (e.g., Kilosort, SpykingCircus). Defining a **custom parameter set** allows for **tuned spike sorting** based on experimental needs.
#
# By the end of this notebook, you will:
# - Inspect available sorting methods and parameter sets
# - Modify default parameters or define a new configuration
# - Insert a new ClusteringParamSet entry into the database

# %% [markdown]
# **_Note:_**
#
# - This notebook uses example data, replace values with actual database entries.
# - You can modify existing parameters or create a new one from scratch.

# %% [markdown]
# ### **Key Steps**

# %% [markdown]
# **- Setup**
#
# **- Step 1: Inspect Available Parameter Sets**
#
# **- Step 2: Define and Insert a New Parameter Set (Optional)**

# %% [markdown]
# ### **Setup**

# %% [markdown]
# First, import the necessary packages for the data pipeline and essential schemas.

# %%
## Ensure the correct working directory

import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import datajoint as dj
# Out:
# c:\Users\Organoid PC\anaconda3\envs\utah_organoids\lib\site-packages\datajoint\plugin.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from workflow.pipeline import ephys
# Out:
# [2026-03-26 14:52:27,936][INFO]: DataJoint 0.14.8 connected to judewerth@db.datajoint.com:3306
# Module stfio is not installed. Make sure .abf files are converted to .pkl in Python 2.

# %% [markdown]
# #### **Step 1: Inspect Available Parameter Sets**

# %% [markdown]
# Before defining a new parameter set, check the existing clustering methods and stored parameter sets.

# %% [markdown]
# View available spike sorting methods supported by SpikeInterface:

# %%
ephys.ClusteringMethod()
# Out:
# *clustering_method    clustering_method_desc
# +-------------------+ +------------------------+
# combinato
# hdsort
# herdingspikes
# ironclust
# kilosort
# kilosort2
# kilosort2.5
# kilosort3
# kilosort4
# klusta
# mountainsort4
# mountainsort5
# pykilosort
# spykingcircus
# spykingcircus2
# tridesclous
# tridesclous2
# waveclus
# waveclus.snippets
# yass
#  (Total: 20)

# %% [markdown]
# Check existing parameter sets:

# %%
ephys.ClusteringParamSet()
# Out:
# *paramset_idx    clustering_method     paramset_desc                            param_set_hash                           params
# +--------------+ +-------------------+ +--------------------------------------+ +--------------------------------------+ +--------+
# 0                spykingcircus2        Default parameters for spyking circus2 u b6fb9ec2-768c-66b0-2b71-9b8ac91e94da     =BLOB=
# 1                spykingcircus2        Default parameter set for spyking circus 434894d0-eb7b-db6c-80e6-638a1322c568     =BLOB=
# 2                kilosort2             kilosort2 with SpikeInterface version 0. 79a731f3-f1b6-c110-5f8a-e25227464de7     =BLOB=
# 5                spykingcircus2        Spyking circus2 with a detection thresho 4c895afd-a1b1-5d64-b747-e8489078e2e3     =BLOB=
# 11               spykingcircus2        waveform>threshold: .25->2               17d41d84-067d-791c-8706-8cab83020b84     =BLOB=
# 12               spykingcircus2        waveform>threshold: .25->2 attempt 2     2b28cf23-2456-8202-b70f-96871b837a26     =BLOB=
# 13               spykingcircus2        waveform>threshold: .25->2 attempt 2     1faf6aee-71d6-fe26-74ec-6bb7cdc0f30f     =BLOB=
# 14               spykingcircus2        apply_preprocessing = False              ce720015-b59a-08d6-198e-def81c860f46     =BLOB=
# 15               spykingcircus2        apply_preprocessing, matched_filtering,  5f7a8362-c31c-061e-14b2-74ad55466546     =BLOB=
# 16               spykingcircus2        default parameters, different format     0a3d0360-c0de-6c30-9c35-7c931a9a6f62     =BLOB=
# 17               spykingcircus2        apply_preprocessing = False              df42ba58-19da-a1a3-116a-647813ef0d4d     =BLOB=
# 18               spykingcircus2        sparsity (snr --> radius(200))           ee18b119-99bd-3793-9e59-b25e78b228b8     =BLOB=
# 19               spykingcircus2        detect threshold (4 --> 8)               f43af517-1b62-39e7-6748-9e58ed925206     =BLOB=
# 20               spykingcircus2        detect threshold (4 --> 15)              9c1ba44e-fcbe-a1bb-852e-678801686e19     =BLOB=
# 21               spykingcircus2        detect threshold (4 --> 8) , min peaks - babe4711-07b6-8755-abbc-53b4faa9820d     =BLOB=
# 22               spykingcircus2        default kilosort3                        1fee6d86-7a41-427d-d09d-07a7ff4b65ce     =BLOB=
# 23               kilosort3             default kilosort3 with no drift correcti 35b4975e-704f-b1a8-1648-5b89086a711c     =BLOB=
# 24               kilosort2             default kilosort2                        512b734c-0b8d-8833-1e2b-b3967e8652de     =BLOB=
# 25               pykilosort            default pykilosort                       d492d2c0-f5f8-5523-f4c6-f6e821fb77ae     =BLOB=
# 26               tridesclous2          default pykilosort                       8a6fff7a-9099-79a2-a33d-7c974dbc86dd     =BLOB=
#    ...
#  (Total: 29)

# %% [markdown]
# Filter for specific sorting methods (e.g., Kilosort):

# %%
ephys.ClusteringParamSet & 'clustering_method LIKE "%kilosort%"'
# Out:
# *paramset_idx    clustering_method     paramset_desc                            param_set_hash                           params
# +--------------+ +-------------------+ +--------------------------------------+ +--------------------------------------+ +--------+
# 2                kilosort2             kilosort2 with SpikeInterface version 0. 79a731f3-f1b6-c110-5f8a-e25227464de7     =BLOB=
# 23               kilosort3             default kilosort3 with no drift correcti 35b4975e-704f-b1a8-1648-5b89086a711c     =BLOB=
# 24               kilosort2             default kilosort2                        512b734c-0b8d-8833-1e2b-b3967e8652de     =BLOB=
# 25               pykilosort            default pykilosort                       d492d2c0-f5f8-5523-f4c6-f6e821fb77ae     =BLOB=
# 27               kilosort3             kilosort3 skipping kilosort preprocessin d74142fc-5a80-d7f4-dff2-607342b0c5c6     =BLOB=
# 250              kilosort2.5           kilosort2.5 params                       00eb514d-f8c8-543b-572a-2ec7fec0acf3     =BLOB=
# 400              kilosort4             Kilosort4 default params with SpikeInter 85dd2fa2-9e7c-7984-9d3c-dc24264c432a     =BLOB=
# 401              kilosort4             Kilosort4 default params with SpikeInter 75a2f1d3-b077-78bb-3a68-b8456644a9f1     =BLOB=
#  (Total: 8)

# %% [markdown]
# ### **Step 2: Define and Insert a New Parameter Set (Optional)**

# %% [markdown]
# A new parameter set can be defined based on a modification of an existing set or a custom configuration from default sorter parameters.

# %% [markdown]
# #### Option 1: Modify an Existing Parameter Set

# %% [markdown]
# To modify an existing parameter set, fetch an existing configuration (e.g., `paramset_idx = 400`), update its values, and insert it as a new entry.

# %%
# Fetch an existing parameter set
param_dict = (ephys.ClusteringParamSet & "paramset_idx = 4037").fetch1()

# Modify specific parameters
param_dict["params"]["SI_SORTING_PARAMS"]["skip_kilosort_preprocessing"] = False
param_dict["paramset_idx"] = 409
param_dict["paramset_desc"] = (
    "Does Kilosort preprocessing, otherwise same as 4037"
)

# Remove hash before inserting as a new entry
param_dict.pop("param_set_hash")

# Confirm changes
param_dict
# Out:
# [2026-03-26 19:10:04,528][WARNING]: Reconnecting to MySQL server.
# {'paramset_idx': 409,
#  'clustering_method': 'kilosort4',
#  'paramset_desc': 'Does Kilosort preprocessing, otherwise same as 4037',
#  'params': {'SI_PREPROCESSING_METHOD': 'organoid_preprocessing',
#   'SI_SORTING_PARAMS': {'scale': 200,
#    'skip_kilosort_preprocessing': False,
#    'do_CAR': False,
#    'n_pcs': 3,
#    'Th_universal': 9.0,
#    'Th_learned': 8.0,
#    'whitening_range': 12,
#    'nearest_chans': 8,
#    'max_channel_distance': 220.0,
#    'nblocks': 0,
#    'keep_good_only': False,
#    'do_correction': False},
#   'SI_POSTPROCESSING_PARAMS': {'extensions': {'random_spikes': {},
#     'waveforms': {},
#     'templates': {},
#     'noise_levels': {},
#     'correlograms': {},
#     'isi_histograms': {},
#     'principal_components': {'n_components': 5, 'mode': 'by_channel_local'},
#     'spike_amplitudes': {},
#     'spike_locations': {},
#     'template_metrics': {'include_multi_channel_metrics': True},
#     'template_similarity': {},
#     'unit_locations': {},
#     'quality_metrics': {}},
#    'job_kwargs': {'n_jobs': 10, 'chunk_duration': '2s'},
#    'export_to_phy': True,
#    'export_report': True}}}

# %%
ephys.ClusteringParamSet() & "paramset_idx > 400"
# Out:
# *paramset_idx    clustering_method     paramset_desc                            param_set_hash                           params
# +--------------+ +-------------------+ +--------------------------------------+ +--------------------------------------+ +--------+
# 401              kilosort4             Kilosort4 standard profile for 100um pro 75a2f1d3-b077-78bb-3a68-b8456644a9f1     =BLOB=
# 403              kilosort4             KKilosort4 conservative profile , chimer 059d3e65-d955-d459-1d11-d2235be42a8a     =BLOB=
# 405              kilosort4             Paramset 401 with installation mode set  ecae73ee-73ba-77bf-c7e4-8cf2f7189067     =BLOB=
# 406              kilosort4             Crazy high threshold (for testing purpos 047b1c3b-cd4c-eceb-26ae-ffc6933243a7     =BLOB=
# 407              kilosort4             Kilosort preprocessing with CAR, no nblo 2e1683fd-09e1-5be0-9c72-0434af478bd4     =BLOB=
# 475              spykingcircus2        Spyking circus2 with a detection thresho cc552535-6116-c01c-01fe-bfaf34fe0e7d     =BLOB=
# 999              kilosort4             Crazy high threshold (for testing purpos faa6b7ef-546f-6456-c146-7ca7c6999f9d     =BLOB=
# 1010             spykingcircus2        Testing insertion of new paramset        a0f9d38c-38b7-3e81-3a08-50dc2062c5dc     =BLOB=
# 3045             kilosort3             param 304 with installation mode = pypi  780dde63-54c0-b215-8aa1-c84bf604ae3c     =BLOB=
# 4005             kilosort4             param 400 with installation mode = pypi  dbb0cd5a-bfe8-510c-a162-715178305749     =BLOB=
# 4035             kilosort4             Conservative Kilosort parameters (403) w 68212a46-8743-c87b-e3f1-43d440f38217     =BLOB=
# 4036             kilosort4             403 parameters with 401 thresholds and n 01e201c5-7357-f759-4037-d24994eed5ec     =BLOB=
# 4037             kilosort4             403 parameters with default thresholds ( 2bd81dd5-45c1-1fb7-eaf8-1637d3c58ecc     =BLOB=
#  (Total: 13)

# %% [markdown]
# ##### Sample parameter dictionary.
#
# It expects to have `SI_SORTING_PARAMS`, `SI_PREPROCESSING_METHOD`, `SI_QUALITY_METRICS_PARAMS`, `SI_JOB_KWARGS`
#
# - `SI_SORTING_PARAMS`: Run `si.sorters.get_default_sorter_params(sorter_name)` to get the default parameter for a sorter. Modify values if needed. If empty, the sorter will be run with the default parameter.
#
# - `SI_PREPROCESSING_METHOD`: Select a preprocesesing function from `si_preprocessing.py`
# - `SI_WAVEFORM_EXTRACTION_PARAMS`: Waveform extraction parameters. If empty, the sorter will use the default parameter.
# - `SI_QUALITY_METRICS_PARAMS`: Quality metric parameters. If empty, the sorter will use the default parameter.
# - `SI_JOB_KWARGS`: Sorter job parameters. If empty, the sorter will use the default parameter.

# %% [markdown]
# Insert modified parameter set into the database:

# %%
# Insert it to the `ephys.ClusteringParamSet` table
ephys.ClusteringParamSet.insert_new_params(
    clustering_method=param_dict["clustering_method"],
    paramset_idx=param_dict['paramset_idx'],
    paramset_desc=param_dict["paramset_desc"],
    params=param_dict["params"],
)

# %% [markdown]
# Verify insertion:

# %%
# Check if the new paramset has been inserted
ephys.ClusteringParamSet & f"paramset_idx = {param_dict['paramset_idx']}"
# Out:
# *paramset_idx    clustering_method     paramset_desc                            param_set_hash                           params
# +--------------+ +-------------------+ +--------------------------------------+ +--------------------------------------+ +--------+
# 409              kilosort4             Does Kilosort preprocessing, otherwise s 7c158bd7-713b-8970-8049-266ad9aac09e     =BLOB=
#  (Total: 1)

# %% [markdown]
# #### Option 2: Create a New Parameter Set from Default Values

# %% [markdown]
# Alternatively, you can create a new parameter set from default sorter settings.

# %% [markdown]
# Get default sorting parameters for `SpykingCircus2`:

# %%
import spikeinterface as si

params_spykingcircus2 = si.sorters.get_default_sorter_params("spykingcircus2")
params_spykingcircus2
# Out:
# {'general': {'ms_before': 2, 'ms_after': 2, 'radius_um': 100},
#  'sparsity': {'method': 'snr',
#   'amplitude_mode': 'peak_to_peak',
#   'threshold': 0.25},
#  'filtering': {'freq_min': 150,
#   'freq_max': 7000,
#   'ftype': 'bessel',
#   'filter_order': 2},
#  'detection': {'peak_sign': 'neg', 'detect_threshold': 4},
#  'selection': {'method': 'uniform',
#   'n_peaks_per_channel': 5000,
#   'min_n_peaks': 100000,
#   'select_per_channel': False,
#   'seed': 42},
#  'apply_motion_correction': True,
#  'motion_correction': {'preset': 'nonrigid_fast_and_accurate'},
#  'merging': {'similarity_kwargs': {'method': 'cosine',
#    'support': 'union',
#    'max_lag_ms': 0.2},
#   'correlograms_kwargs': {},
#   'auto_merge': {'min_spikes': 10, 'corr_diff_thresh': 0.25}},
#  'clustering': {'legacy': True},
#  'matching': {'method': 'wobble'},
#  'apply_preprocessing': True,
#  'matched_filtering': True,
#  'cache_preprocessing': {'mode': 'memory',
#   'memory_limit': 0.5,
#   'delete_cache': True},
#  'multi_units_only': False,
#  'job_kwargs': {'n_jobs': 0.8},
#  'debug': False}

# %% [markdown]
# Modify specific parameters:

# %%
params_spykingcircus2["detect_threshold"] = 10  # Adjust detection threshold

# %%
params = {}
params["SI_PREPROCESSING_METHOD"] = "CatGT"
params["SI_SORTING_PARAMS"] = params_spykingcircus2
params["SI_POSTPROCESSING_PARAMS"] = {
    "extensions": {
        "random_spikes": {},
        "waveforms": {},
        "templates": {},
        "noise_levels": {},
        # "amplitude_scalings": {},
        "correlograms": {},
        "isi_histograms": {},
        "principal_components": {"n_components": 5, "mode": "by_channel_local"},
        "spike_amplitudes": {},
        "spike_locations": {},
        "template_metrics": {"include_multi_channel_metrics": True},
        "template_similarity": {},
        "unit_locations": {},
        "quality_metrics": {},
    },
    "job_kwargs": {"n_jobs": 0.8, "chunk_duration": "2s"},
    "export_to_phy": True,
    "export_report": True,
}

# %% [markdown]
# Insert the new parameter set into the database:

# %%
ephys.ClusteringParamSet.insert_new_params(
    clustering_method="spykingcircus2",
    paramset_idx=102,
    paramset_desc="spykingcircus2 with SpikeInterface version 0.101+ and `detect_threshold=10`",
    params=params,
)

# %% [markdown]
# Verify the new parameter set:

# %%
ephys.ClusteringParamSet & "paramset_idx = 102"
# Out:
# *paramset_idx    clustering_method     paramset_desc                            param_set_hash                           params
# +--------------+ +-------------------+ +--------------------------------------+ +--------------------------------------+ +--------+
# 102              spykingcircus2        spykingcircus2 with SpikeInterface versi 8a9e5403-fd6e-fa93-1486-212f57613b64     =BLOB=
#  (Total: 1)

# %% [markdown]
# ### **Next Steps**

# %% [markdown]
# Now that the parameter set is created, you can:
# - Assign it to a clustering task (`CREATE_new_clustering_task.ipynb`)
# - Run spike sorting with the new parameter set (`RUN` notebook)
