# %% [markdown]
# # DataJoint Workflow Guide for Uploading Session Data to the Cloud

# %% [markdown]
# This notebook provides a walkthrough for uploading the data to the cloud.

# %% [markdown]
# **_Note:_**
#
# - The examples in this notebook use a sample dataset. Replace these entries with your actual database entries to access and analyze your data.

# %% [markdown]
# ### **Key Steps**
#
# - **Setup**
#
# - **Step 1: Initiate data upload**

# %% [markdown]
# ### **Setup**

# %% [markdown]
# Begin by importing the necessary libraries for the data pipeline and key schemas.

# %%
## Ensure the correct working directory

import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import datajoint as dj

# %%
from workflow.utils.initiate_session import upload_session_data

# %% [markdown]
# #### **Step 1: Initiate data upload**

# %% [markdown]
# ##### Example
#
# If the data is located at `/Users/milagros/Documents/data/organoids/inbox/21-24_raw/..`, where `local_outbox:"/Users/milagros/Documents/data/organoids/` in the `config.yaml`, then run:
#
# ```python
# upload_session_data('21-24_raw')
# ```

# %% [markdown]
# Proceed to upload the data to AWS S3 bucket:

# %%
upload_session_data("O21-24_raw")
# Out:
# [2024-08-13 21:38:57,871][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-08-13 21:38:57,873][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-08-13 21:38:57,873][_oidc_login][WARNING]: User authentication required to use DataJoint SciOps CLI tools. We'll be launching a web browser to authenticate your DataJoint account.
# [2024-08-13 21:38:57,882][_oidc_login][INFO]: Browser available. Launching...
# [2024-08-13 21:38:58,111][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:28282
#  * Running on http://192.168.1.40:28282
# Press CTRL+C to quit
#  * Serving Flask app 'browser-interface'
#  * Debug mode: off
# 127.0.0.1 - - [13/Aug/2024 21:38:58] "GET /login-completed?session_state=44bd6bfe-2a46-4d4e-8f60-1e4164ce465d&code=7ccd4e85-22e7-444e-9fbd-f88046e81392.44bd6bfe-2a46-4d4e-8f60-1e4164ce465d.3e9a100b-e191-41ba-b6a5-f63ee13bc599 HTTP/1.1" 200 -
# [2024-08-13 21:38:59,637][_oidc_login][INFO]: User successfully authenticated.
# [2024-08-13 21:39:02,674][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-08-13 21:39:02,674][_resolve_upload_mapping][INFO]: Resolving upload mapping...
# [2024-08-13 21:39:04,084][flush][INFO]: Total Uploading Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,085][flush][INFO]:
# [2024-08-13 21:39:04,085][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/O21-24_raw/test.txt->utah_organoids/inbox/O21-24_raw/test.txt Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,085][flush][INFO]:
# [2024-08-13 21:39:04,292][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/O21-24_raw/test.txt->utah_organoids/inbox/O21-24_raw/test.txt Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,293][flush][INFO]: Total Uploading Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,474][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-08-13 21:39:04,474][_resolve_upload_mapping][INFO]: Resolving upload mapping...
# [2024-08-13 21:39:04,656][flush][INFO]: Total Uploading Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,658][flush][INFO]:
# [2024-08-13 21:39:04,659][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/O21-24_raw/upload_completed.txt->utah_organoids/inbox/O21-24_raw/upload_completed.txt Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,659][flush][INFO]:
# [2024-08-13 21:39:04,859][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/O21-24_raw/upload_completed.txt->utah_organoids/inbox/O21-24_raw/upload_completed.txt Progress: 0.00B [00:00, ?B/s]
# [2024-08-13 21:39:04,861][flush][INFO]: Total Uploading Progress: 0.00B [00:00, ?B/s]
